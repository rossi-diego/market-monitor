# %%
import pandas as pd
import numpy as np

# %%
caminho_df_2015 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2015.xlsx'
caminho_df_2016 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2016.xlsx'
caminho_df_2017 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2017.xlsx'
caminho_df_2018 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2018.xlsx'
caminho_df_2019 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2019.xlsx'
caminho_df_2020 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2020.xlsx'
caminho_df_2021 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2021.xlsx'
caminho_df_2022 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2022.xlsx'
caminho_df_2023 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2023.xlsx'
caminho_df_2024 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2024.xlsx'
caminho_df_2025 = r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\Informações Mercado 2025.xlsx'

df_2015 = pd.read_excel(caminho_df_2015)
df_2016 = pd.read_excel(caminho_df_2016)
df_2017 = pd.read_excel(caminho_df_2017)
df_2018 = pd.read_excel(caminho_df_2018)
df_2019 = pd.read_excel(caminho_df_2019)
df_2020 = pd.read_excel(caminho_df_2020)
df_2021 = pd.read_excel(caminho_df_2021)
df_2022 = pd.read_excel(caminho_df_2022)
df_2023 = pd.read_excel(caminho_df_2023)
df_2024 = pd.read_excel(caminho_df_2024)
df_2025 = pd.read_excel(caminho_df_2025)

# %%
df.head()
# Out:
#                     Unnamed: 0  2019-01-01 00:00:00  2019-01-02 00:00:00  \
# 0  Petróleo Brent (US$/barril)                  NaN              54.9100
# 1     Petróleo Brent (US$/ton)                  NaN             402.4903
# 2              Gasoil (US$/mt)                  NaN                  NaN
# 3      FAME Biodiesel (US$/mt)                  NaN                  NaN
# 4          Prêmio RME (US$/mt)                  NaN                  NaN
#
#    2019-01-03 00:00:00  2019-01-04 00:00:00  2019-01-05 00:00:00  \
# 0              55.9500              57.0600                  NaN
# 1             410.1135             418.2498                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    2019-01-06 00:00:00  2019-01-07 00:00:00  2019-01-08 00:00:00  \
# 0                  NaN              57.3300              58.7200
# ...

# %%
df.shape
# Out:
# (144, 367)

# %%
# Carregar toda a aba "Dados"

df_2015 = df_2015.rename(columns={"Informações de acompanhamento do mercado": "ativo"})
df_2015 = df_2015.dropna(subset=['ativo'])
df_2015 = df_2015.set_index('ativo')
df_2015.columns = pd.to_datetime(df_2015.columns, errors="coerce")
df_2015 = df_2015.T
df_2015 = df_2015['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2016 = df_2016.rename(columns={"Unnamed: 0": "ativo"})
df_2016 = df_2016.dropna(subset=['ativo'])
df_2016 = df_2016.set_index('ativo')
df_2016.columns = pd.to_datetime(df_2016.columns, errors="coerce")
df_2016 = df_2016.T
df_2016 = df_2016['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2017 = df_2017.rename(columns={"Unnamed: 0": "ativo"})
df_2017 = df_2017.dropna(subset=['ativo'])
df_2017 = df_2017.set_index('ativo')
df_2017.columns = pd.to_datetime(df_2017.columns, errors="coerce")
df_2017 = df_2017.T
df_2017 = df_2017['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2018 = df_2018.rename(columns={"Unnamed: 0": "ativo"})
df_2018 = df_2018.dropna(subset=['ativo'])
df_2018 = df_2018.set_index('ativo')
df_2018.columns = pd.to_datetime(df_2018.columns, errors="coerce")
df_2018 = df_2018.T
df_2018 = df_2018['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2019 = df_2019.rename(columns={"Unnamed: 0": "ativo"})
df_2019 = df_2019.dropna(subset=['ativo'])
df_2019 = df_2019.set_index('ativo')
df_2019.columns = pd.to_datetime(df_2019.columns, errors="coerce")
df_2019 = df_2019.T
df_2019 = df_2019['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2020 = df_2020.rename(columns={"Unnamed: 0": "ativo"})
df_2020 = df_2020.dropna(subset=['ativo'])
df_2020 = df_2020.set_index('ativo')
df_2020.columns = pd.to_datetime(df_2020.columns, errors="coerce")
df_2020 = df_2020.T
df_2020 = df_2020['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2021 = df_2021.rename(columns={"Unnamed: 0": "ativo"})
df_2021 = df_2021.dropna(subset=['ativo'])
df_2021 = df_2021.set_index('ativo')
df_2021.columns = pd.to_datetime(df_2021.columns, errors="coerce")
df_2021 = df_2021.T
df_2021 = df_2021['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2022 = df_2022.rename(columns={"Unnamed: 0": "ativo"})
df_2022 = df_2022.dropna(subset=['ativo'])
df_2022 = df_2022.set_index('ativo')
df_2022.columns = pd.to_datetime(df_2022.columns, errors="coerce")
df_2022 = df_2022.T
df_2022 = df_2022['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2023 = df_2023.rename(columns={"Unnamed: 0": "ativo"})
df_2023 = df_2023.dropna(subset=['ativo'])
df_2023 = df_2023.set_index('ativo')
df_2023.columns = pd.to_datetime(df_2023.columns, errors="coerce")
df_2023 = df_2023.T
df_2023 = df_2023['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2024 = df_2024.rename(columns={"Unnamed: 0": "ativo"})
df_2024 = df_2024.dropna(subset=['ativo'])
df_2024 = df_2024.set_index('ativo')
df_2024.columns = pd.to_datetime(df_2024.columns, errors="coerce")
df_2024 = df_2024.T
df_2024 = df_2024['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

df_2025 = df_2025.rename(columns={"Unnamed: 0": "ativo"})
df_2025 = df_2025.dropna(subset=['ativo'])
df_2025 = df_2025.set_index('ativo')
df_2025.columns = pd.to_datetime(df_2025.columns, errors="coerce")
df_2025 = df_2025.T
df_2025 = df_2025['Prêmio Exportação RIG (US$/ton)', 'Soja Rio Grande do Sul (R$/saca 60kg)', 'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)', 'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)', 
'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (US$/ton)', 'Óleo de Soja LEM (R$/ton)', 'Óleo de Soja Rio Verde (R$/ton)', 'Óleo de Soja Cuiabá (R$/ton)', 
'Boi Gordo São Paulo (R$/@)', 'Boi Gordo RS (R$/@)', 'Gordura Animal Safras (R$/ton)']

lista_dfs = [df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023, df_2024, df_2025]

df_safras = pd.concat(lista_dfs, ignore_index=True)

df_safras.to_excel(r'X:\Riscos de Mercado\market-monitor-painel\data\market_intelligence_data\safras_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\diego.santanna\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df_2019
# Out:
# ativo       Petróleo Brent (US$/barril)  Petróleo Brent (US$/ton)  \
# 2019-01-01                          NaN                       NaN
# 2019-01-02                        54.91                  402.4903
# 2019-01-03                        55.95                  410.1135
# 2019-01-04                        57.06                  418.2498
# 2019-01-05                          NaN                       NaN
# ...                                 ...                       ...
# 2019-12-27                        68.16                  499.6128
# 2019-12-28                          NaN                       NaN
# 2019-12-29                          NaN                       NaN
# 2019-12-30                        68.16                  499.6128
# 2019-12-31                        68.16                  499.6128
#
# ativo       Gasoil (US$/mt)  FAME Biodiesel (US$/mt)  Prêmio RME (US$/mt)  \
# 2019-01-01              NaN                      NaN                  NaN
# ...

# %%
df_2019.columns
# Out:
# Index(['Petróleo Brent (US$/barril)', 'Petróleo Brent (US$/ton)',
#        'Gasoil (US$/mt)', 'FAME Biodiesel (US$/mt)', 'Prêmio RME (US$/mt)',
#        'Soja Chicago (US$/saca 60kg)', 'Farelo Chicago (US$/ton curta)',
#        'Óleo de Soja Chicago (pontos)', 'Óleo de Soja Chicago (US$/ton)',
#        'Múltiplo OV Cbot/Brendt', 'Prêmio Exportação RIG (pontos)',
#        'Óleo de Soja FOB RIG (US$/ton)', 'Óleo de Soja FOB RIG (R$/ton)',
#        'Prêmio Exportação RIG (US$/ton)', 'Prêmio Exportação PRG (pontos)',
#        'Óleo de Soja FOB PRG (US$/ton)', 'Óleo de Soja FOB PRG (R$/ton)',
#        'Taxa Dólar', 'Soja Rio Grande do Sul (R$/saca 60kg)',
#        'Soja Bahia (R$/saca 60kg)', 'Soja Paraná (R$/saca 60kg)',
#        'Soja Mato Grosso (R$/saca 60kg)', 'Soja Goiás (R$/saca 60kg)',
#        'Farelo Veranópolis (R$/ton)', 'Óleo de Soja CIF Veranópolis (R$/ton)',
#        'Óleo de Soja CIF Veranópolis (US$/ton)', 'Múltiplo OV/Brendt',
# ...
